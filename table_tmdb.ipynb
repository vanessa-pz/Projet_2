# %%
pip install gdown
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown

# %%
import pandas as pd
# Chargement du fichier CSV
# ID du fichier
file_id = '1VB5_gl1fnyBDzcIOXZ5vUSbCY68VZN1v'
# Générer l'URL de téléchargement
url = f'https://drive.google.com/uc?id={file_id}'
output = 'df.csv'
# Télécharger le fichier CSV
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1VB5_gl1fnyBDzcIOXZ5vUSbCY68VZN1v
# From (redirected): https://drive.google.com/uc?id=1VB5_gl1fnyBDzcIOXZ5vUSbCY68VZN1v&confirm=t&uuid=b2822beb-be30-437d-903a-82973d424b4d
# To: c:\Users\nessp\OneDrive\Desktop\df.csv
# 100%|██████████| 157M/157M [00:34<00:00, 4.48MB/s]
# 'df.csv'

# %%
import pandas as pd

# Supposons que df soit votre DataFrame initial

# Filtrer les lignes contenant 'US' dans la colonne production_companies_name
filtered_df = df[df['production_companies_country'].str.contains('US', na=False, case=False)]

# Afficher le DataFrame filtré
display(filtered_df)
# Out:
#         adult                     backdrop_path    budget  \
# 0       False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg         0
# 5       False  /c1BaOxC8bo5ACFYkYYxL0bBWRaq.jpg   4000000
# 6       False  /bGMqHn0H2UY6SPZ5Vch4YJM2jDO.jpg  21000000
# 9       False  /2w4xG178RpB4MDAIfTkqAuSJzec.jpg  11000000
# 10      False  /yzqaKAhglTrkeOfuIXYYArf0WnA.jpg  94000000
# ...       ...                               ...       ...
# 164337  False                               NaN         0
# 164338  False                               NaN         0
# 164342  False                               NaN         0
# 164383  False                               NaN         0
# 164391  False                               NaN         0
#
#                                             genres  \
# 0                                       ['Comedy']
# 5                              ['Crime', 'Comedy']
# 6                  ['Action', 'Crime', 'Thriller']
# 9       ['Adventure', 'Action', 'Science Fiction']
# ...

# %%
filtered_df.shape
# Out:
# (23590, 25)

# %%
# Filtrer les lignes contenant 'US' dans la colonne production_companies_name
filtered_df = df[df['spoken_languages'].str.contains('fr', na=False, case=False)]

# Afficher le DataFrame filtré
display(filtered_df)
# Out:
#         adult                     backdrop_path    budget  \
# 2       False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg         0
# 21      False  /lVy5Zqcty2NfemqKYbVJfdg44rK.jpg  30000000
# 25      False  /9Qs9oyn4iE8QtQjGZ0Hp2WyYNXT.jpg  31500000
# 33      False  /1IWaKG7AWiYMhADxhGtnElDJAGI.jpg  29000000
# 44      False   /ELsTifJ2lu4vsMhoHeZ5EnncHw.jpg  70000000
# ...       ...                               ...       ...
# 309024  False                               NaN         0
# 309278  False  /weanMzu1Gufj1dzOPCXljONZhRX.jpg         0
# 309283  False  /A94D7d8LaPjpSV3uiP82ZbbS30F.jpg         0
# 309333  False                               NaN         0
# 309433  False                               NaN         0
#
#                                             genres  \
# 2                             ['Drama', 'Romance']
# 21                             ['Action', 'Crime']
# 25                                ['Drama', 'War']
# 33      ['Science Fiction', 'Thriller', 'Mystery']
# ...

# %%
# Supprimer les lignes où vote_count est égal à 0
filtered_df = filtered_df[filtered_df['vote_average'] != 0]

# Réinitialiser les index après suppression (optionnel)
filtered_df.reset_index(drop=True, inplace=True)

# Afficher le DataFrame mis à jour
display(filtered_df)
# Out:
#        adult                     backdrop_path    budget  \
# 0      False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg         0
# 1      False  /lVy5Zqcty2NfemqKYbVJfdg44rK.jpg  30000000
# 2      False  /9Qs9oyn4iE8QtQjGZ0Hp2WyYNXT.jpg  31500000
# 3      False  /1IWaKG7AWiYMhADxhGtnElDJAGI.jpg  29000000
# 4      False   /ELsTifJ2lu4vsMhoHeZ5EnncHw.jpg  70000000
# ...      ...                               ...       ...
# 16940  False                               NaN         0
# 16941  False                               NaN         0
# 16942  False                               NaN         0
# 16943  False  /A94D7d8LaPjpSV3uiP82ZbbS30F.jpg         0
# 16944  False                               NaN         0
#
#                                            genres  \
# 0                            ['Drama', 'Romance']
# 1                             ['Action', 'Crime']
# 2                                ['Drama', 'War']
# 3      ['Science Fiction', 'Thriller', 'Mystery']
# ...

# %%
# Calcul de la moyenne de la colonne 'vote_average'
moyenne_vote_average = filtered_df['vote_average'].mean()

# Filtrer les lignes où 'vote_average' est supérieur ou égal à la moyenne
filtered_df = filtered_df[filtered_df['vote_average'] >= moyenne_vote_average]

# Réinitialiser les index après la suppression (optionnel)
filtered_df.reset_index(drop=True, inplace=True)

# Afficher le DataFrame filtré
display(filtered_df)
# Out:
#       adult                     backdrop_path    budget  \
# 0     False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg         0
# 1     False  /lVy5Zqcty2NfemqKYbVJfdg44rK.jpg  30000000
# 2     False  /9Qs9oyn4iE8QtQjGZ0Hp2WyYNXT.jpg  31500000
# 3     False  /1IWaKG7AWiYMhADxhGtnElDJAGI.jpg  29000000
# 4     False   /ELsTifJ2lu4vsMhoHeZ5EnncHw.jpg  70000000
# ...     ...                               ...       ...
# 8639  False                               NaN         0
# 8640  False                               NaN         0
# 8641  False  /9AkWQSb5Zj5NlYRXipw4f4WHtgr.jpg         0
# 8642  False  /x3tXDViQGjkEpEoC5VlcBhwEGcv.jpg     13500
# 8643  False  /A94D7d8LaPjpSV3uiP82ZbbS30F.jpg         0
#
#                                           genres  \
# 0                           ['Drama', 'Romance']
# 1                            ['Action', 'Crime']
# 2                               ['Drama', 'War']
# 3     ['Science Fiction', 'Thriller', 'Mystery']
# ...

# %%
filtered_df.shape
# Out:
# (8644, 25)

# %%
# Supprimer les doublons basés sur la colonne 'imdb_id'
filtered_df = filtered_df.drop_duplicates(subset='imdb_id')

# Réinitialiser l'index après suppression (optionnel)
filtered_df.reset_index(drop=True, inplace=True)

# Afficher le DataFrame sans doublons
display(filtered_df)
# Out:
#       adult                     backdrop_path    budget  \
# 0     False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg         0
# 1     False  /lVy5Zqcty2NfemqKYbVJfdg44rK.jpg  30000000
# 2     False  /9Qs9oyn4iE8QtQjGZ0Hp2WyYNXT.jpg  31500000
# 3     False  /1IWaKG7AWiYMhADxhGtnElDJAGI.jpg  29000000
# 4     False   /ELsTifJ2lu4vsMhoHeZ5EnncHw.jpg  70000000
# ...     ...                               ...       ...
# 8639  False                               NaN         0
# 8640  False                               NaN         0
# 8641  False  /9AkWQSb5Zj5NlYRXipw4f4WHtgr.jpg         0
# 8642  False  /x3tXDViQGjkEpEoC5VlcBhwEGcv.jpg     13500
# 8643  False  /A94D7d8LaPjpSV3uiP82ZbbS30F.jpg         0
#
#                                           genres  \
# 0                           ['Drama', 'Romance']
# 1                            ['Action', 'Crime']
# 2                               ['Drama', 'War']
# 3     ['Science Fiction', 'Thriller', 'Mystery']
# ...

# %%
filtered_df.shape
# Out:
# (8644, 25)

# %%
# Supprimer les colonnes spécifiques
filtered_df = filtered_df.drop(columns=['adult', 'budget', 'homepage', 'vote_count', 'production_companies_country'])

# Afficher le DataFrame après suppression des colonnes
display(filtered_df)
# Out:
#                          backdrop_path  \
# 0     /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg
# 1     /lVy5Zqcty2NfemqKYbVJfdg44rK.jpg
# 2     /9Qs9oyn4iE8QtQjGZ0Hp2WyYNXT.jpg
# 3     /1IWaKG7AWiYMhADxhGtnElDJAGI.jpg
# 4      /ELsTifJ2lu4vsMhoHeZ5EnncHw.jpg
# ...                                ...
# 8639                               NaN
# 8640                               NaN
# 8641  /9AkWQSb5Zj5NlYRXipw4f4WHtgr.jpg
# 8642  /x3tXDViQGjkEpEoC5VlcBhwEGcv.jpg
# 8643  /A94D7d8LaPjpSV3uiP82ZbbS30F.jpg
#
#                                           genres      id    imdb_id  \
# 0                           ['Drama', 'Romance']    8773  tt0055747
# 1                            ['Action', 'Crime']      24  tt0266697
# 2                               ['Drama', 'War']      28  tt0078788
# 3     ['Science Fiction', 'Thriller', 'Mystery']      63  tt0114746
# 4       ['Comedy', 'Fantasy', 'Science Fiction']      75  tt0116996
# ...                                          ...     ...        ...
# ...

# %%
filtered_df.shape
# Out:
# (8644, 20)
