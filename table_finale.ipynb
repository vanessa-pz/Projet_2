# %%
pip install gdown
# Out:
# Requirement already satisfied: gdown in c:\users\win10\anaconda3\lib\site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\win10\anaconda3\lib\site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in c:\users\win10\anaconda3\lib\site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in c:\users\win10\anaconda3\lib\site-packages (from gdown) (2.32.2)
# Requirement already satisfied: tqdm in c:\users\win10\anaconda3\lib\site-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\win10\anaconda3\lib\site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\win10\anaconda3\lib\site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\win10\anaconda3\lib\site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\win10\anaconda3\lib\site-packages (from requests[socks]->gdown) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\win10\anaconda3\lib\site-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\win10\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\win10\anaconda3\lib\site-packages (from tqdm->gdown) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime
from datetime import timedelta
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import gdown

# %%
# ID du fichier Google Drive
file_id_tmdb = '1SSeKdAQQqU6QbWwKfiKNcqNEqHxbwGm3'
url_tmdb = f'https://drive.google.com/uc?id={file_id_tmdb}'

# Chemin de sauvegarde du fichier téléchargé
output = 'tmdb.csv'

# Télécharger le fichier
gdown.download(url_tmdb, output, quiet=False)

# Lire le fichier CSV avec pandas
try:
    df_tmdb = pd.read_csv(output, delimiter=',', on_bad_lines='skip', engine='python')
    if df_tmdb.empty:
        print("Le fichier est vide.")
    else:
        # Afficher les premières lignes du DataFrame
        display(df_tmdb.head())
except pd.errors.EmptyDataError:
    print("Aucune donnée à analyser dans le fichier.")
except Exception as e:
    print(f"Une erreur est survenue : {e}")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1SSeKdAQQqU6QbWwKfiKNcqNEqHxbwGm3
# From (redirected): https://drive.google.com/uc?id=1SSeKdAQQqU6QbWwKfiKNcqNEqHxbwGm3&confirm=t&uuid=33a51c19-30d9-41ae-af25-d32dcde7d975
# To: c:\Users\Win10\Desktop\projet 2 bdd\tmdb.csv
# 100%|██████████| 157M/157M [00:15<00:00, 10.3MB/s]
#    adult                     backdrop_path  budget  \
# 0  False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg       0
# 1  False                               NaN       0
# 2  False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg       0
# 3  False  /hQ4pYsIbP22TMXOUdSfC2mjWrO0.jpg       0
# 4  False  /l94l89eMmFKh7na2a1u5q67VgNx.jpg       0
#
#                            genres homepage    id    imdb_id original_language  \
# 0                      ['Comedy']      NaN  3924  tt0029927                en
# 1                   ['Adventure']      NaN  6124  tt0011436                de
# 2            ['Drama', 'Romance']      NaN  8773  tt0055747                fr
# 3    ['Drama', 'Comedy', 'Crime']      NaN     2  tt0094675                fi
# 4  ['Drama', 'Comedy', 'Romance']      NaN     3  tt0092149                fi
#
#          original_title                                           overview  \
# 0               Blondie  Blondie and Dagwood are about to celebrate the...
# 1   Der Mann ohne Namen                                                NaN
# 2   L'Amour à vingt ans  Love at Twenty unites five directors from five...
# 3                 Ariel  Taisto Kasurinen is a Finnish coal miner whose...
# 4  Varjoja paratiisissa  An episode in the life of Nikander, a garbage ...
#
#    ...  runtime                spoken_languages    status  \
# 0  ...       70                          ['en']  Released
# 1  ...      420                              []  Released
# 2  ...      110  ['it', 'ja', 'pl', 'fr', 'de']  Released
# 3  ...       73                          ['fi']  Released
# 4  ...       76                          ['en']  Released
#
#                                              tagline  \
# 0  The favorite comic strip of millions at last o...
# 1                                                NaN
# 2               The Intimate Secrets of Young Lovers
# 3                                                NaN
# 4                                                NaN
#
#                            title  video vote_average vote_count  \
# 0                        Blondie  False        7.214          7
# 1  Peter Voss, Thief of Millions  False        0.000          0
# 2                 Love at Twenty  False        6.700         41
# 3                          Ariel  False        7.046        248
# 4            Shadows in Paradise  False        7.182        269
#
#                            production_companies_name  \
# 0                              ['Columbia Pictures']
# 1                                                 []
# 2  ['Ulysse Productions', 'Unitec Films', 'Cinese...
# 3                      ['Villealfa Filmproductions']
# 4                      ['Villealfa Filmproductions']
#
#              production_companies_country
# 0                                  ['US']
# 1                                      []
# 2  ['', 'NZ', 'IT', 'JP', 'DE', 'PL', '']
# 3                                  ['FI']
# 4                                  ['FI']
#
# [5 rows x 25 columns]

# %%
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309572 entries, 0 to 309571
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   adult                         309572 non-null  bool
#  1   backdrop_path                 151760 non-null  object
#  2   budget                        309572 non-null  int64
#  3   genres                        309572 non-null  object
#  4   homepage                      44262 non-null   object
#  5   id                            309572 non-null  int64
#  6   imdb_id                       309572 non-null  object
#  7   original_language             309572 non-null  object
#  8   original_title                309572 non-null  object
#  9   overview                      282512 non-null  object
#  10  popularity                    309572 non-null  float64
#  11  poster_path                   264159 non-null  object
#  12  production_countries          309572 non-null  object
#  13  release_date                  301339 non-null  object
#  14  revenue                       309572 non-null  int64
#  15  runtime                       309572 non-null  int64
#  16  spoken_languages              309572 non-null  object
#  17  status                        309572 non-null  object
#  18  tagline                       74573 non-null   object
#  19  title                         309572 non-null  object
#  20  video                         309572 non-null  bool
#  21  vote_average                  309572 non-null  float64
#  22  vote_count                    309572 non-null  int64
#  23  production_companies_name     309572 non-null  object
#  24  production_companies_country  164438 non-null  object
# dtypes: bool(2), float64(2), int64(5), object(16)
# memory usage: 54.9+ MB

# %%
# Vérifier un échantillon du contenu de la colonne 'genres'
print(df_tmdb['genres'].head())
# Out:
# 0                        ['Comedy']
# 1                     ['Adventure']
# 2              ['Drama', 'Romance']
# 3      ['Drama', 'Comedy', 'Crime']
# 4    ['Drama', 'Comedy', 'Romance']
# Name: genres, dtype: object

# %%
# Convertir chaque élément de la colonne 'genres' en une chaîne de caractères si nécessaire
# Supposons que chaque élément est une chaîne de caractères ou une liste de chaînes de caractères
# Vous pouvez ajuster la logique de conversion en fonction du contenu réel

def convert_genres(genres):
    if isinstance(genres, list):
        return ' '.join(genres)
    elif isinstance(genres, str):
        return genres
    else:
        return str(genres)

df_tmdb['genres'] = df_tmdb['genres'].apply(convert_genres)
# Vérifier que la conversion a réussi
print(df_tmdb['genres'].head())
# Out:
# 0                        ['Comedy']
# 1                     ['Adventure']
# 2              ['Drama', 'Romance']
# 3      ['Drama', 'Comedy', 'Crime']
# 4    ['Drama', 'Comedy', 'Romance']
# Name: genres, dtype: object

# %%
# Filtrer les lignes où 'genres' contient 'Adventure' ou 'Comedy'
df_tmdb_filtered = df_tmdb[df_tmdb['genres'].str.contains('Adventure|Comedy', na=False)]

# Afficher les 15 premières lignes du DataFrame filtré
display(df_tmdb_filtered.head(2))
# Out:
#    adult                     backdrop_path  budget         genres homepage  \
# 0  False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg       0     ['Comedy']      NaN
# 1  False                               NaN       0  ['Adventure']      NaN
#
#      id    imdb_id original_language       original_title  \
# 0  3924  tt0029927                en              Blondie
# 1  6124  tt0011436                de  Der Mann ohne Namen
#
#                                             overview  ...  runtime  \
# 0  Blondie and Dagwood are about to celebrate the...  ...       70
# 1                                                NaN  ...      420
#
#   spoken_languages    status  \
# 0           ['en']  Released
# 1               []  Released
#
#                                              tagline  \
# 0  The favorite comic strip of millions at last o...
# 1                                                NaN
#
#                            title  video vote_average vote_count  \
# 0                        Blondie  False        7.214          7
# 1  Peter Voss, Thief of Millions  False        0.000          0
#
#   production_companies_name production_companies_country
# 0     ['Columbia Pictures']                       ['US']
# 1                        []                           []
#
# [2 rows x 25 columns]

# %%
# Filtrer les lignes où 'spoken_languages' contient 'fr'
df_tmdb_fr = df_tmdb_filtered[df_tmdb_filtered['spoken_languages'].str.contains('fr', na=False)]
display(df_tmdb_fr)
# Out:
#         adult                     backdrop_path    budget  \
# 44      False   /ELsTifJ2lu4vsMhoHeZ5EnncHw.jpg  70000000
# 77      False  /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg         0
# 102     False  /oT9diLGD1cgPdvkxqHIJcuSXKUT.jpg  14600000
# 130     False  /9B3NnLM7Uct4eSB5Th9aqVQa8uT.jpg         0
# 135     False  /3oNDTUxv2lLWMqt5R12A0vM5dBn.jpg         0
# ...       ...                               ...       ...
# 308128  False                               NaN         0
# 308260  False  /z9kgYGIZbp4vI4LwOrMM4kCe1Je.jpg         0
# 308324  False                               NaN         0
# 308413  False                               NaN         0
# 309283  False  /A94D7d8LaPjpSV3uiP82ZbbS30F.jpg         0
#
#                                            genres  \
# 44       ['Comedy', 'Fantasy', 'Science Fiction']
# 77                 ['Comedy', 'Drama', 'Mystery']
# 102     ['Romance', 'Fantasy', 'Drama', 'Comedy']
# 130                ['Drama', 'Romance', 'Comedy']
# 135                ['Comedy', 'Romance', 'Drama']
# ...                                           ...
# 308128                        ['Drama', 'Comedy']
# 308260                     ['Comedy', 'TV Movie']
# 308324                                 ['Comedy']
# 308413                     ['Comedy', 'TV Movie']
# 309283                                 ['Comedy']
#
#                                                homepage      id    imdb_id  \
# 44      https://www.warnerbros.com/movies/mars-attacks/      75  tt0116996
# 77                                                  NaN     109  tt0111507
# 102                                                 NaN     137  tt0107048
# 130                                                 NaN     166  tt0082100
# 135                                                 NaN     171  tt0083686
# ...                                                 ...     ...        ...
# 308128                                              NaN  225255  tt0468834
# 308260                                              NaN  226288  tt0313313
# 308324                                              NaN  226855  tt0277844
# 308413                                              NaN  227460  tt0303166
# 309283                                              NaN  232251  tt0167083
#
#        original_language                      original_title  \
# 44                    en                       Mars Attacks!
# 77                    fr              Trois couleurs : Blanc
# 102                   en                       Groundhog Day
# 130                   fr                             La Boum
# 135                   fr                           La Boum 2
# ...                  ...                                 ...
# 308128                lb                      Perl oder Pica
# 308260                fr            Le Bourgeois gentilhomme
# 308324                fr                Max en convalescence
# 308413                fr                             Ubu Roi
# 309283                cs  Co je doma to se počítá, pánové...
#
#                                                  overview  ...  runtime  \
# 44      A fleet of Martian spacecraft surrounds the wo...  ...      106
# 77      Polish immigrant Karol Karol finds himself out...  ...       92
# 102     A narcissistic TV weatherman, along with his a...  ...      101
# 130     A thirteen-year-old French girl deals with mov...  ...      110
# 135     A young French teenage girl after moving to a ...  ...      109
# ...                                                   ...  ...      ...
# 308128  October 1962, the height of the Cuban missile ...  ...       90
# 308260  Le Bourgeois gentilhomme satirizes attempts at...  ...      130
# 308324  To reassure his fans, Max Linder has been film...  ...       11
# 308413  Based on Alfredy Jarrry's 1896 play about a gr...  ...       95
# 309283                      Czech comedy from the 70ties.  ...       84
#
#                 spoken_languages    status  \
# 44                  ['en', 'fr']  Released
# 77            ['fr', 'hu', 'pl']  Released
# 102           ['en', 'fr', 'it']  Released
# 130                       ['fr']  Released
# 135                       ['fr']  Released
# ...                          ...       ...
# 308128              ['fr', 'lb']  Released
# 308260                    ['fr']  Released
# 308324                    ['fr']  Released
# 308413                    ['fr']  Released
# 309283  ['en', 'cs', 'fr', 'de']  Released
#
#                                                   tagline  \
# 44                            Nice planet. We'll take it!
# 77                                                    NaN
# 102     He’s having the worst day of his life… Over an...
# 130                                                   NaN
# 135                                                   NaN
# ...                                                   ...
# 308128                                                NaN
# 308260                                                NaN
# 308324                                                NaN
# 308413                                                NaN
# 309283                                                NaN
#
#                                      title  video vote_average vote_count  \
# 44                           Mars Attacks!  False        6.394       4864
# 77                     Three Colors: White  False        7.482        989
# 102                          Groundhog Day  False        7.603       6963
# 130                              The Party  False        6.605       1019
# 135                            The Party 2  False        6.454        570
# ...                                    ...    ...          ...        ...
# 308128                      Little Secrets  False        5.300          9
# 308260                  Would-Be Gentleman  False        0.000          0
# 308324                 Max Is Convalescent  False        6.200          8
# 308413                             Ubu Roi  False        5.100          5
# 309283  Co je doma to se počítá, pánové...  False        6.800          6
#
#                                 production_companies_name  \
# 44      ['Tim Burton Productions', 'Warner Bros. Pictu...
# 77      ['Le Studio Canal+', 'France 3 Cinéma', 'Eurim...
# 102                                 ['Columbia Pictures']
# 130     ['Productions Marcel Dassault', 'Gaumont', 'Ga...
# 135     ['Productions Marcel Dassault', 'Gaumont', 'Ga...
# ...                                                   ...
# 308128           ['Red Lion', 'Amour Fou Filmproduktion']
# 308260  ['Office de Radiodiffusion Télévision Française']
# 308324                                   ['Pathé Frères']
# 308413  ['Office de Radiodiffusion Télévision Française']
# 309283                       ['Filmové studio Barrandov']
#
#        production_companies_country
# 44                       ['', 'US']
# 77         ['FR', 'FR', 'FR', 'US']
# 102                          ['US']
# 130              ['FR', 'FR', 'FR']
# 135              ['FR', 'FR', 'FR']
# ...                             ...
# 308128                          NaN
# 308260                          NaN
# 308324                          NaN
# 308413                          NaN
# 309283                          NaN
#
# [6383 rows x 25 columns]

# %%
# Obtenir les valeurs uniques dans la colonne 'original_language'
fr_en = df_tmdb_fr['original_language'].unique()
print(fr_en)
# Out:
# ['en' 'fr' 'it' 'de' 'el' 'sv' 'cs' 'nl' 'ar' 'es' 'ro' 'ja' 'cn' 'sr'
#  'bo' 'hi' 'da' 'pl' 'ru' 'he' 'is' 'tr' 'et' 'pt' 'eu' 'fi' 'uk' 'fa'
#  'hu' 'ca' 'zh' 'no' 'lb' 'gd' 'ko' 'th' 'hy' 'ka' 'wo' 'cr' 'fo' 'ml'
#  'sh' 'xx' 'id']

# %%
# Obtenir les valeurs uniques dans la colonne 'status'
stat = df_tmdb_fr['status'].unique()
print(stat)
# Out:
# ['Released' 'Planned' 'In Production' 'Post Production']

# %%
# Filtrer les lignes où 'status' contient 'Released'
df_tmdb_fr = df_tmdb_fr[df_tmdb_fr['status'].str.contains('Released', na=False)]
display(df_tmdb_fr)
# Out:
#         adult                     backdrop_path    budget  \
# 44      False   /ELsTifJ2lu4vsMhoHeZ5EnncHw.jpg  70000000
# 77      False  /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg         0
# 102     False  /oT9diLGD1cgPdvkxqHIJcuSXKUT.jpg  14600000
# 130     False  /9B3NnLM7Uct4eSB5Th9aqVQa8uT.jpg         0
# 135     False  /3oNDTUxv2lLWMqt5R12A0vM5dBn.jpg         0
# ...       ...                               ...       ...
# 308128  False                               NaN         0
# 308260  False  /z9kgYGIZbp4vI4LwOrMM4kCe1Je.jpg         0
# 308324  False                               NaN         0
# 308413  False                               NaN         0
# 309283  False  /A94D7d8LaPjpSV3uiP82ZbbS30F.jpg         0
#
#                                            genres  \
# 44       ['Comedy', 'Fantasy', 'Science Fiction']
# 77                 ['Comedy', 'Drama', 'Mystery']
# 102     ['Romance', 'Fantasy', 'Drama', 'Comedy']
# 130                ['Drama', 'Romance', 'Comedy']
# 135                ['Comedy', 'Romance', 'Drama']
# ...                                           ...
# 308128                        ['Drama', 'Comedy']
# 308260                     ['Comedy', 'TV Movie']
# 308324                                 ['Comedy']
# 308413                     ['Comedy', 'TV Movie']
# 309283                                 ['Comedy']
#
#                                                homepage      id    imdb_id  \
# 44      https://www.warnerbros.com/movies/mars-attacks/      75  tt0116996
# 77                                                  NaN     109  tt0111507
# 102                                                 NaN     137  tt0107048
# 130                                                 NaN     166  tt0082100
# 135                                                 NaN     171  tt0083686
# ...                                                 ...     ...        ...
# 308128                                              NaN  225255  tt0468834
# 308260                                              NaN  226288  tt0313313
# 308324                                              NaN  226855  tt0277844
# 308413                                              NaN  227460  tt0303166
# 309283                                              NaN  232251  tt0167083
#
#        original_language                      original_title  \
# 44                    en                       Mars Attacks!
# 77                    fr              Trois couleurs : Blanc
# 102                   en                       Groundhog Day
# 130                   fr                             La Boum
# 135                   fr                           La Boum 2
# ...                  ...                                 ...
# 308128                lb                      Perl oder Pica
# 308260                fr            Le Bourgeois gentilhomme
# 308324                fr                Max en convalescence
# 308413                fr                             Ubu Roi
# 309283                cs  Co je doma to se počítá, pánové...
#
#                                                  overview  ...  runtime  \
# 44      A fleet of Martian spacecraft surrounds the wo...  ...      106
# 77      Polish immigrant Karol Karol finds himself out...  ...       92
# 102     A narcissistic TV weatherman, along with his a...  ...      101
# 130     A thirteen-year-old French girl deals with mov...  ...      110
# 135     A young French teenage girl after moving to a ...  ...      109
# ...                                                   ...  ...      ...
# 308128  October 1962, the height of the Cuban missile ...  ...       90
# 308260  Le Bourgeois gentilhomme satirizes attempts at...  ...      130
# 308324  To reassure his fans, Max Linder has been film...  ...       11
# 308413  Based on Alfredy Jarrry's 1896 play about a gr...  ...       95
# 309283                      Czech comedy from the 70ties.  ...       84
#
#                 spoken_languages    status  \
# 44                  ['en', 'fr']  Released
# 77            ['fr', 'hu', 'pl']  Released
# 102           ['en', 'fr', 'it']  Released
# 130                       ['fr']  Released
# 135                       ['fr']  Released
# ...                          ...       ...
# 308128              ['fr', 'lb']  Released
# 308260                    ['fr']  Released
# 308324                    ['fr']  Released
# 308413                    ['fr']  Released
# 309283  ['en', 'cs', 'fr', 'de']  Released
#
#                                                   tagline  \
# 44                            Nice planet. We'll take it!
# 77                                                    NaN
# 102     He’s having the worst day of his life… Over an...
# 130                                                   NaN
# 135                                                   NaN
# ...                                                   ...
# 308128                                                NaN
# 308260                                                NaN
# 308324                                                NaN
# 308413                                                NaN
# 309283                                                NaN
#
#                                      title  video vote_average vote_count  \
# 44                           Mars Attacks!  False        6.394       4864
# 77                     Three Colors: White  False        7.482        989
# 102                          Groundhog Day  False        7.603       6963
# 130                              The Party  False        6.605       1019
# 135                            The Party 2  False        6.454        570
# ...                                    ...    ...          ...        ...
# 308128                      Little Secrets  False        5.300          9
# 308260                  Would-Be Gentleman  False        0.000          0
# 308324                 Max Is Convalescent  False        6.200          8
# 308413                             Ubu Roi  False        5.100          5
# 309283  Co je doma to se počítá, pánové...  False        6.800          6
#
#                                 production_companies_name  \
# 44      ['Tim Burton Productions', 'Warner Bros. Pictu...
# 77      ['Le Studio Canal+', 'France 3 Cinéma', 'Eurim...
# 102                                 ['Columbia Pictures']
# 130     ['Productions Marcel Dassault', 'Gaumont', 'Ga...
# 135     ['Productions Marcel Dassault', 'Gaumont', 'Ga...
# ...                                                   ...
# 308128           ['Red Lion', 'Amour Fou Filmproduktion']
# 308260  ['Office de Radiodiffusion Télévision Française']
# 308324                                   ['Pathé Frères']
# 308413  ['Office de Radiodiffusion Télévision Française']
# 309283                       ['Filmové studio Barrandov']
#
#        production_companies_country
# 44                       ['', 'US']
# 77         ['FR', 'FR', 'FR', 'US']
# 102                          ['US']
# 130              ['FR', 'FR', 'FR']
# 135              ['FR', 'FR', 'FR']
# ...                             ...
# 308128                          NaN
# 308260                          NaN
# 308324                          NaN
# 308413                          NaN
# 309283                          NaN
#
# [6335 rows x 25 columns]

# %%
#supprimer les colonnes 'budget', 'id', 'vote_count' et 'revenue'
tmdb_1= df_tmdb_fr.drop(columns=['budget', 'id', 'vote_count', 'revenue'])
display(tmdb_1.head(2))
# Out:
#     adult                     backdrop_path  \
# 44  False   /ELsTifJ2lu4vsMhoHeZ5EnncHw.jpg
# 77  False  /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg
#
#                                       genres  \
# 44  ['Comedy', 'Fantasy', 'Science Fiction']
# 77            ['Comedy', 'Drama', 'Mystery']
#
#                                            homepage    imdb_id  \
# 44  https://www.warnerbros.com/movies/mars-attacks/  tt0116996
# 77                                              NaN  tt0111507
#
#    original_language          original_title  \
# 44                en           Mars Attacks!
# 77                fr  Trois couleurs : Blanc
#
#                                              overview  popularity  \
# 44  A fleet of Martian spacecraft surrounds the wo...      21.051
# 77  Polish immigrant Karol Karol finds himself out...      13.473
#
#                          poster_path  ... release_date runtime  \
# 44  /hll4O5vSAfnZDb6JbnP06GPtz7b.jpg  ...   1996-12-12     106
# 77  /fdIet3NSa27gobMbaUml66oCQNT.jpg  ...   1994-01-26      92
#
#       spoken_languages    status                      tagline  \
# 44        ['en', 'fr']  Released  Nice planet. We'll take it!
# 77  ['fr', 'hu', 'pl']  Released                          NaN
#
#                   title  video  vote_average  \
# 44        Mars Attacks!  False         6.394
# 77  Three Colors: White  False         7.482
#
#                             production_companies_name  \
# 44  ['Tim Burton Productions', 'Warner Bros. Pictu...
# 77  ['Le Studio Canal+', 'France 3 Cinéma', 'Eurim...
#
#    production_companies_country
# 44                   ['', 'US']
# 77     ['FR', 'FR', 'FR', 'US']
#
# [2 rows x 21 columns]

# %%
tmdb_1.head(2)
# Out:
#     adult                     backdrop_path  \
# 44  False   /ELsTifJ2lu4vsMhoHeZ5EnncHw.jpg
# 77  False  /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg
#
#                                       genres  \
# 44  ['Comedy', 'Fantasy', 'Science Fiction']
# 77            ['Comedy', 'Drama', 'Mystery']
#
#                                            homepage    imdb_id  \
# 44  https://www.warnerbros.com/movies/mars-attacks/  tt0116996
# 77                                              NaN  tt0111507
#
#    original_language          original_title  \
# 44                en           Mars Attacks!
# 77                fr  Trois couleurs : Blanc
#
#                                              overview  popularity  \
# 44  A fleet of Martian spacecraft surrounds the wo...      21.051
# 77  Polish immigrant Karol Karol finds himself out...      13.473
#
#                          poster_path  ... release_date runtime  \
# 44  /hll4O5vSAfnZDb6JbnP06GPtz7b.jpg  ...   1996-12-12     106
# 77  /fdIet3NSa27gobMbaUml66oCQNT.jpg  ...   1994-01-26      92
#
#       spoken_languages    status                      tagline  \
# 44        ['en', 'fr']  Released  Nice planet. We'll take it!
# 77  ['fr', 'hu', 'pl']  Released                          NaN
#
#                   title  video  vote_average  \
# 44        Mars Attacks!  False         6.394
# 77  Three Colors: White  False         7.482
#
#                             production_companies_name  \
# 44  ['Tim Burton Productions', 'Warner Bros. Pictu...
# 77  ['Le Studio Canal+', 'France 3 Cinéma', 'Eurim...
#
#    production_companies_country
# 44                   ['', 'US']
# 77     ['FR', 'FR', 'FR', 'US']
#
# [2 rows x 21 columns]

# %%
# Convertir 'release_date' en format datetime (si ce n'est pas déjà fait)
tmdb_1['release_date'] = pd.to_datetime(tmdb_1['release_date'], errors='coerce')

# Extraire l'année de la colonne 'release_date'
tmdb_1['release_year'] = tmdb_1['release_date'].dt.year

# Afficher les premières lignes pour vérifier le résultat
print(tmdb_1[['release_date', 'release_year']].head())
# Out:
#     release_date  release_year
# 44    1996-12-12        1996.0
# 77    1994-01-26        1994.0
# 102   1993-02-11        1993.0
# 130   1980-12-17        1980.0
# 135   1982-12-08        1982.0

# %%
tmdb_1.head(2)
# Out:
#     adult                     backdrop_path  \
# 44  False   /ELsTifJ2lu4vsMhoHeZ5EnncHw.jpg
# 77  False  /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg
#
#                                       genres  \
# 44  ['Comedy', 'Fantasy', 'Science Fiction']
# 77            ['Comedy', 'Drama', 'Mystery']
#
#                                            homepage    imdb_id  \
# 44  https://www.warnerbros.com/movies/mars-attacks/  tt0116996
# 77                                              NaN  tt0111507
#
#    original_language          original_title  \
# 44                en           Mars Attacks!
# 77                fr  Trois couleurs : Blanc
#
#                                              overview  popularity  \
# 44  A fleet of Martian spacecraft surrounds the wo...      21.051
# 77  Polish immigrant Karol Karol finds himself out...      13.473
#
#                          poster_path  ... runtime    spoken_languages  \
# 44  /hll4O5vSAfnZDb6JbnP06GPtz7b.jpg  ...     106        ['en', 'fr']
# 77  /fdIet3NSa27gobMbaUml66oCQNT.jpg  ...      92  ['fr', 'hu', 'pl']
#
#       status                      tagline                title  video  \
# 44  Released  Nice planet. We'll take it!        Mars Attacks!  False
# 77  Released                          NaN  Three Colors: White  False
#
#    vote_average                          production_companies_name  \
# 44        6.394  ['Tim Burton Productions', 'Warner Bros. Pictu...
# 77        7.482  ['Le Studio Canal+', 'France 3 Cinéma', 'Eurim...
#
#     production_companies_country release_year
# 44                    ['', 'US']       1996.0
# 77      ['FR', 'FR', 'FR', 'US']       1994.0
#
# [2 rows x 22 columns]

# %%
# Filtrer les lignes où 'release_year' est supérieur ou égal à 1990
tmdb_90 = tmdb_1[tmdb_1['release_year'] >= 1990]

tmdb_90.shape
# Out:
# (4080, 22)

# %%
tmdb_90.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4080 entries, 44 to 308128
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   adult                         4080 non-null   bool
#  1   backdrop_path                 2993 non-null   object
#  2   genres                        4080 non-null   object
#  3   homepage                      509 non-null    object
#  4   imdb_id                       4080 non-null   object
#  5   original_language             4080 non-null   object
#  6   original_title                4080 non-null   object
#  7   overview                      3661 non-null   object
#  8   popularity                    4080 non-null   float64
#  9   poster_path                   3930 non-null   object
#  10  production_countries          4080 non-null   object
#  11  release_date                  4080 non-null   datetime64[ns]
#  12  runtime                       4080 non-null   int64
#  13  spoken_languages              4080 non-null   object
#  14  status                        4080 non-null   object
#  15  tagline                       664 non-null    object
#  16  title                         4080 non-null   object
#  17  video                         4080 non-null   bool
#  18  vote_average                  4080 non-null   float64
#  19  production_companies_name     4080 non-null   object
#  20  production_companies_country  2210 non-null   object
#  21  release_year                  4080 non-null   float64
# dtypes: bool(2), datetime64[ns](1), float64(3), int64(1), object(15)
# memory usage: 677.3+ KB

# %%
# ID du fichier Google Drive
file_id_table = '1BgXeRjXAJyZrAMY0oP3Y5pJ0xIW1clzf'

# URL pour télécharger le fichier
url_table = f'https://drive.google.com/uc?id={file_id_table}'

# Chemin de sauvegarde du fichier téléchargé
output = 'table_principale.csv'

# Télécharger le fichier
gdown.download(url_table, output, quiet=False)

# Lire le fichier CSV avec pandas
try:
    df_table = pd.read_csv(output, delimiter=',', on_bad_lines='skip', engine='python')
    if df_table.empty:
        print("Le fichier est vide.")
    else:
        # Afficher les premières lignes du DataFrame
        display(df_table.head())
except pd.errors.EmptyDataError:
    print("Aucune donnée à analyser dans le fichier.")
except Exception as e:
    print(f"Une erreur est survenue : {e}")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BgXeRjXAJyZrAMY0oP3Y5pJ0xIW1clzf
# To: c:\Users\Win10\Desktop\projet 2 bdd\table_principale.csv
# 100%|██████████| 1.29M/1.29M [00:00<00:00, 5.14MB/s]
#       tconst  averageRating      numVotes  ordering     nconst category  \
# 0  tt0139645       6.400675  54558.048108       1.0  nm0000103  actress
# 1  tt0119304       5.100000   9061.000000       1.0  nm0000106  actress
# 2  tt0120523       6.400675  54558.048108       1.0  nm0000106  actress
# 3  tt0151738       6.000000  99378.000000       1.0  nm0000106  actress
# 4  tt0200027       6.500000  30914.000000       1.0  nm0000106  actress
#
#                       title language        types  startYear  runtimeMinutes  \
# 0     Life in the Fast Lane       en  imdbDisplay     1998.0            92.0
# 1                Home Fries       en  imdbDisplay     1998.0            91.0
# 2          Wishful Thinking       en  imdbDisplay     1997.0            93.0
# 3         Never Been Kissed       en  imdbDisplay     1999.0           107.0
# 4  Riding in Cars with Boys       en  imdbDisplay     2001.0           132.0
#
#                    genres     primaryName  birthYear
# 0                  Comedy    Fairuza Balk     1974.0
# 1    Comedy,Drama,Romance  Drew Barrymore     1975.0
# 2          Comedy,Romance  Drew Barrymore     1975.0
# 3    Comedy,Drama,Romance  Drew Barrymore     1975.0
# 4  Biography,Comedy,Drama  Drew Barrymore     1975.0

# %%
# Renommer les colonnes
tmdb_90.rename(columns={'imdb_id': 'tconst', 'title': 'title_imdb'}, inplace=True)

# Afficher les premières lignes pour vérifier le changement
display(tmdb_90.head())
# Out:
# C:\Users\Win10\AppData\Local\Temp\ipykernel_22604\1154809610.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmdb_90.rename(columns={'imdb_id': 'tconst', 'title': 'title_imdb'}, inplace=True)
#      adult                     backdrop_path  \
# 44   False   /ELsTifJ2lu4vsMhoHeZ5EnncHw.jpg
# 77   False  /2eBL3wXDZqemW8SJ1RNxqtx6bgJ.jpg
# 102  False  /oT9diLGD1cgPdvkxqHIJcuSXKUT.jpg
# 155  False  /9Y9K6LeLrMeofOvX7hZW36Aj3OG.jpg
# 251  False  /bHePzkyRcMhnab2qZbhj1bCElnf.jpg
#
#                                         genres  \
# 44    ['Comedy', 'Fantasy', 'Science Fiction']
# 77              ['Comedy', 'Drama', 'Mystery']
# 102  ['Romance', 'Fantasy', 'Drama', 'Comedy']
# 155                      ['Comedy', 'Romance']
# 251             ['Comedy', 'Drama', 'Fantasy']
#
#                                               homepage     tconst  \
# 44     https://www.warnerbros.com/movies/mars-attacks/  tt0116996
# 77                                                 NaN  tt0111507
# 102                                                NaN  tt0107048
# 155              https://www.miramax.com/movie/amelie/  tt0211915
# 251  http://www.lasciencedesreves-lefilm.com/accuei...  tt0354899
#
#     original_language                       original_title  \
# 44                 en                        Mars Attacks!
# 77                 fr               Trois couleurs : Blanc
# 102                en                        Groundhog Day
# 155                fr  Le Fabuleux Destin d'Amélie Poulain
# 251                fr                 La Science des rêves
#
#                                               overview  popularity  \
# 44   A fleet of Martian spacecraft surrounds the wo...      21.051
# 77   Polish immigrant Karol Karol finds himself out...      13.473
# 102  A narcissistic TV weatherman, along with his a...      21.795
# 155  At a tiny Parisian café, the adorable yet pain...      26.104
# 251  A man entranced by his dreams and imagination ...       8.741
#
#                           poster_path  ... runtime    spoken_languages  \
# 44   /hll4O5vSAfnZDb6JbnP06GPtz7b.jpg  ...     106        ['en', 'fr']
# 77   /fdIet3NSa27gobMbaUml66oCQNT.jpg  ...      92  ['fr', 'hu', 'pl']
# 102  /qIwyDf5k0eNsrfQjd0HCkeraNGD.jpg  ...     101  ['en', 'fr', 'it']
# 155  /oTKduWL2tpIKEmkAqF4mFEAWAsv.jpg  ...     122        ['fr', 'ru']
# 251  /1qCq228LsNtUseCnNE7Naw6NBUz.jpg  ...     105  ['en', 'fr', 'es']
#
#        status                                            tagline  \
# 44   Released                        Nice planet. We'll take it!
# 77   Released                                                NaN
# 102  Released  He’s having the worst day of his life… Over an...
# 155  Released           One person can change your life forever.
# 251  Released                  Close your eyes. Open your heart.
#
#                title_imdb  video vote_average  \
# 44          Mars Attacks!  False        6.394
# 77    Three Colors: White  False        7.482
# 102         Groundhog Day  False        7.603
# 155                Amélie  False        7.902
# 251  The Science of Sleep  False        7.052
#
#                              production_companies_name  \
# 44   ['Tim Burton Productions', 'Warner Bros. Pictu...
# 77   ['Le Studio Canal+', 'France 3 Cinéma', 'Eurim...
# 102                              ['Columbia Pictures']
# 155  ['France 3 Cinéma', 'Claudie Ossard Production...
# 251  ['Partizan Films', 'Gaumont', 'France 3 Cinéma...
#
#                           production_companies_country release_year
# 44                                          ['', 'US']       1996.0
# 77                            ['FR', 'FR', 'FR', 'US']       1994.0
# 102                                             ['US']       1993.0
# 155  ['FR', '', '', '', '', '', 'FR', 'DE', 'FR', '...       2001.0
# 251                 ['', 'FR', 'FR', 'FR', 'IT', 'FR']       2006.0
#
# [5 rows x 22 columns]

# %%
# Fusionner les deux DataFrames sur la colonne 'tconst'
merged_df = pd.merge(tmdb_90, df_table, on='tconst', how='outer')

# Afficher les premières lignes pour vérifier la fusion
display(merged_df.head())
# Out:
#    adult                     backdrop_path                          genres_x  \
# 0  False  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg  ['Romance', 'Fantasy', 'Comedy']
# 1    NaN                               NaN                               NaN
# 2  False  /6tRdTNdcmdBlTGyJ924ISyJDABA.jpg    ['Comedy', 'Drama', 'Romance']
# 3  False  /uEPLeurEn2dp54f5owtMC3PeiPN.jpg  ['Crime', 'Action', 'Adventure']
# 4  False  /inHgpiOAddL4Y53EvHf9B5lf2Sc.jpg            ['Drama', 'Adventure']
#
#   homepage     tconst original_language         original_title  \
# 0      NaN  tt0035423                en         Kate & Leopold
# 1      NaN  tt0096222               NaN                    NaN
# 2      NaN  tt0097106                fr     Conte de printemps
# 3      NaN  tt0097318                en       Eye of the Widow
# 4      NaN  tt0097462                fr  Guerriers et Captives
#
#                                             overview  popularity  \
# 0  When her scientist ex-boyfriend discovers a po...      15.770
# 1                                                NaN         NaN
# 2  The story of an introverted young girl  just r...       9.163
# 3  A new international terrorist group attack the...       0.742
# 4  Patagonia, Argentina, 1880s. During the Conque...       0.960
#
#                         poster_path  ...     nconst category  \
# 0  /mUvikzKJJSg9khrVdxK8kg3TMHA.jpg  ...        NaN      NaN
# 1                               NaN  ...  nm0510903    actor
# 2  /bP2qpuzQPBBBJa4kOhvLvOOiASq.jpg  ...        NaN      NaN
# 3  /1Ela9pkCRCPugwasp8hdR1BpfXb.jpg  ...        NaN      NaN
# 4  /ytYs98qqVmiY45cxkqNgJbj8uDL.jpg  ...        NaN      NaN
#
#                title language        types startYear runtimeMinutes  \
# 0                NaN      NaN          NaN       NaN            NaN
# 1  To Miss with Love       en  imdbDisplay    1992.0           90.0
# 2                NaN      NaN          NaN       NaN            NaN
# 3                NaN      NaN          NaN       NaN            NaN
# 4                NaN      NaN          NaN       NaN            NaN
#
#                genres_y  primaryName birthYear
# 0                   NaN          NaN       NaN
# 1  Comedy,Drama,Romance    Jimmy Lin    1974.0
# 2                   NaN          NaN       NaN
# 3                   NaN          NaN       NaN
# 4                   NaN          NaN       NaN
#
# [5 rows x 35 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12379 entries, 0 to 12378
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   adult                         4080 non-null   object
#  1   backdrop_path                 2993 non-null   object
#  2   genres_x                      4080 non-null   object
#  3   homepage                      509 non-null    object
#  4   tconst                        12379 non-null  object
#  5   original_language             4080 non-null   object
#  6   original_title                4080 non-null   object
#  7   overview                      3661 non-null   object
#  8   popularity                    4080 non-null   float64
#  9   poster_path                   3930 non-null   object
#  10  production_countries          4080 non-null   object
#  11  release_date                  4080 non-null   datetime64[ns]
#  12  runtime                       4080 non-null   float64
#  13  spoken_languages              4080 non-null   object
#  14  status                        4080 non-null   object
#  15  tagline                       664 non-null    object
#  16  title_imdb                    4080 non-null   object
#  17  video                         4080 non-null   object
#  18  vote_average                  4080 non-null   float64
#  19  production_companies_name     4080 non-null   object
#  20  production_companies_country  2210 non-null   object
#  21  release_year                  4080 non-null   float64
#  22  averageRating                 8917 non-null   float64
#  23  numVotes                      8917 non-null   float64
#  24  ordering                      8917 non-null   float64
#  25  nconst                        8917 non-null   object
#  26  category                      8917 non-null   object
#  27  title                         8917 non-null   object
#  28  language                      8917 non-null   object
#  29  types                         8917 non-null   object
#  30  startYear                     8917 non-null   float64
#  31  runtimeMinutes                8917 non-null   float64
#  32  genres_y                      8917 non-null   object
#  33  primaryName                   8917 non-null   object
#  34  birthYear                     8917 non-null   float64
# dtypes: datetime64[ns](1), float64(10), object(24)
# memory usage: 3.3+ MB

# %%
merged_df.columns
# Out:
# Index(['adult', 'backdrop_path', 'genres_x', 'homepage', 'tconst',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_countries', 'release_date', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title_imdb', 'video',
#        'vote_average', 'production_companies_name',
#        'production_companies_country', 'release_year', 'averageRating',
#        'numVotes', 'ordering', 'nconst', 'category', 'title', 'language',
#        'types', 'startYear', 'runtimeMinutes', 'genres_y', 'primaryName',
#        'birthYear'],
#       dtype='object')

# %%
# Combiner les valeurs des deux colonnes 'genre' en une seule
merged_df['genres'] = merged_df['genres_x'].fillna('') + ',' + merged_df['genres_y'].fillna('')

# %%
# Supprimer les colonnes supplémentaires 'genre_tmdb' et 'genre_table'
merged_df = merged_df.drop(columns=['genres_x', 'genres_y'])

# Afficher les premières lignes pour vérifier la fusion
display(merged_df.head())
# Out:
#    adult                     backdrop_path homepage     tconst  \
# 0  False  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg      NaN  tt0035423
# 1    NaN                               NaN      NaN  tt0096222
# 2  False  /6tRdTNdcmdBlTGyJ924ISyJDABA.jpg      NaN  tt0097106
# 3  False  /uEPLeurEn2dp54f5owtMC3PeiPN.jpg      NaN  tt0097318
# 4  False  /inHgpiOAddL4Y53EvHf9B5lf2Sc.jpg      NaN  tt0097462
#
#   original_language         original_title  \
# 0                en         Kate & Leopold
# 1               NaN                    NaN
# 2                fr     Conte de printemps
# 3                en       Eye of the Widow
# 4                fr  Guerriers et Captives
#
#                                             overview  popularity  \
# 0  When her scientist ex-boyfriend discovers a po...      15.770
# 1                                                NaN         NaN
# 2  The story of an introverted young girl  just r...       9.163
# 3  A new international terrorist group attack the...       0.742
# 4  Patagonia, Argentina, 1880s. During the Conque...       0.960
#
#                         poster_path production_countries  ...     nconst  \
# 0  /mUvikzKJJSg9khrVdxK8kg3TMHA.jpg               ['US']  ...        NaN
# 1                               NaN                  NaN  ...  nm0510903
# 2  /bP2qpuzQPBBBJa4kOhvLvOOiASq.jpg               ['FR']  ...        NaN
# 3  /1Ela9pkCRCPugwasp8hdR1BpfXb.jpg         ['ES', 'FR']  ...        NaN
# 4  /ytYs98qqVmiY45cxkqNgJbj8uDL.jpg   ['AR', 'FR', 'CH']  ...        NaN
#
#    category              title language        types startYear runtimeMinutes  \
# 0       NaN                NaN      NaN          NaN       NaN            NaN
# 1     actor  To Miss with Love       en  imdbDisplay    1992.0           90.0
# 2       NaN                NaN      NaN          NaN       NaN            NaN
# 3       NaN                NaN      NaN          NaN       NaN            NaN
# 4       NaN                NaN      NaN          NaN       NaN            NaN
#
#    primaryName birthYear                             genres
# 0          NaN       NaN  ['Romance', 'Fantasy', 'Comedy'],
# 1    Jimmy Lin    1974.0              ,Comedy,Drama,Romance
# 2          NaN       NaN    ['Comedy', 'Drama', 'Romance'],
# 3          NaN       NaN  ['Crime', 'Action', 'Adventure'],
# 4          NaN       NaN            ['Drama', 'Adventure'],
#
# [5 rows x 34 columns]

# %%
merged_df.shape
# Out:
# (12379, 34)

# %%
# Trouver les NaN dans tout le DataFrame
nan_counts = merged_df.isna().sum()

# Afficher le nombre de NaN par colonne
print(nan_counts)
# Out:
# adult                            8299
# backdrop_path                    9386
# homepage                        11870
# tconst                              0
# original_language                8299
# original_title                   8299
# overview                         8718
# popularity                       8299
# poster_path                      8449
# production_countries             8299
# release_date                     8299
# runtime                          8299
# spoken_languages                 8299
# status                           8299
# tagline                         11715
# title_imdb                       8299
# video                            8299
# vote_average                     8299
# production_companies_name        8299
# production_companies_country    10169
# release_year                     8299
# averageRating                    3462
# numVotes                         3462
# ordering                         3462
# nconst                           3462
# category                         3462
# title                            3462
# language                         3462
# types                            3462
# startYear                        3462
# runtimeMinutes                   3462
# primaryName                      3462
# birthYear                        3462
# genres                              0
# dtype: int64

# %% [markdown]
# Supprimer les colonnes 'homepage', 'tagline', 'production_companies_country' car nombre de NaN > 10000

# %%
# Supprimer les colonnes spécifiées
merged_df = merged_df.drop(columns=['homepage', 'tagline', 'production_companies_country'])

# %%
# Combiner les colonnes 'title_imdb' et 'title' en une seule colonne
#merged_df['titles'] = merged_df['title_imdb'].fillna('') + ' - ' + merged_df['title'].fillna('')

# Supprimer les colonnes 'title_imdb' et 'title'
#merged_df = merged_df.drop(columns=['title_imdb', 'title'])

# Afficher les premières lignes pour vérifier
display(merged_df.head())
# Out:
#    adult                     backdrop_path     tconst  \
# 0  False  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg  tt0035423
# 1    NaN                               NaN  tt0096222
# 2  False  /6tRdTNdcmdBlTGyJ924ISyJDABA.jpg  tt0097106
# 3  False  /uEPLeurEn2dp54f5owtMC3PeiPN.jpg  tt0097318
# 4  False  /inHgpiOAddL4Y53EvHf9B5lf2Sc.jpg  tt0097462
#
#                                             overview  popularity  \
# 0  When her scientist ex-boyfriend discovers a po...      15.770
# 1                                                NaN         NaN
# 2  The story of an introverted young girl  just r...       9.163
# 3  A new international terrorist group attack the...       0.742
# 4  Patagonia, Argentina, 1880s. During the Conque...       0.960
#
#                         poster_path production_countries    status  \
# 0  /mUvikzKJJSg9khrVdxK8kg3TMHA.jpg               ['US']  Released
# 1                               NaN                  NaN       NaN
# 2  /bP2qpuzQPBBBJa4kOhvLvOOiASq.jpg               ['FR']  Released
# 3  /1Ela9pkCRCPugwasp8hdR1BpfXb.jpg         ['ES', 'FR']  Released
# 4  /ytYs98qqVmiY45cxkqNgJbj8uDL.jpg   ['AR', 'FR', 'CH']  Released
#
#                            production_companies_name  averageRating  ordering  \
# 0                     ['Konrad Pictures', 'Miramax']            NaN       NaN
# 1                                                NaN       6.400675       1.0
# 2  ['Les Films du Losange', 'Investimage', 'Compa...            NaN       NaN
# 3               ['New Vision Films', 'Eridan Films']            NaN       NaN
# 4  ['INCAA', 'JEMPSA', 'TSR', 'Les Films du phare...            NaN       NaN
#
#   category primaryName  birthYear                             genres  \
# 0      NaN         NaN        NaN  ['Romance', 'Fantasy', 'Comedy'],
# 1    actor   Jimmy Lin     1974.0              ,Comedy,Drama,Romance
# 2      NaN         NaN        NaN    ['Comedy', 'Drama', 'Romance'],
# 3      NaN         NaN        NaN  ['Crime', 'Action', 'Adventure'],
# 4      NaN         NaN        NaN            ['Drama', 'Adventure'],
#
#                       titles          languages_combined  \
# 0          Kate & Leopold -         ['en', 'fr', 'it'],
# 1        - To Miss with Love                        , en
# 2    A Tale of Springtime -                     ['fr'],
# 3        Eye of the Widow -   ['ar', 'en', 'fr', 'es'],
# 4  Warriors and Prisoners -               ['fr', 'es'],
#
#                   votes   runtime start_year
# 0              6.326 /    / 118.0  2001.0 -
# 1   / 54558.04810794954   90.0 /    - 1992.0
# 2                6.9 /    / 103.0  1990.0 -
# 3                3.0 /     / 95.0  1991.0 -
# 4                0.0 /     / 99.0  1990.0 -

# %%
merged_df.columns
# Out:
# Index(['adult', 'backdrop_path', 'tconst', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'video', 'vote_average', 'production_companies_name',
#        'release_year', 'averageRating', 'numVotes', 'ordering', 'nconst',
#        'category', 'language', 'types', 'startYear', 'runtimeMinutes',
#        'primaryName', 'birthYear', 'genres', 'titles'],
#       dtype='object')

# %%
# Trouver les NaN dans tout le DataFrame
nan_counts = merged_df.isna().sum()

# Afficher le nombre de NaN par colonne
print(nan_counts)
# Out:
# adult                        8299
# backdrop_path                9386
# tconst                          0
# original_language            8299
# original_title               8299
# overview                     8718
# popularity                   8299
# poster_path                  8449
# production_countries         8299
# release_date                 8299
# runtime                      8299
# spoken_languages             8299
# status                       8299
# video                        8299
# vote_average                 8299
# production_companies_name    8299
# release_year                 8299
# averageRating                3462
# numVotes                     3462
# ordering                     3462
# nconst                       3462
# category                     3462
# language                     3462
# types                        3462
# startYear                    3462
# runtimeMinutes               3462
# primaryName                  3462
# birthYear                    3462
# genres                          0
# titles                          0
# dtype: int64

# %%
# Combiner les colonnes 'spoken_languages' et 'language' en une seule colonne
merged_df['languages_combined'] = merged_df['spoken_languages'].fillna('') + ', ' + merged_df['language'].fillna('')

# Supprimer les colonnes 'spoken_languages' et 'language'
merged_df = merged_df.drop(columns=['spoken_languages', 'language'])

# Afficher les premières lignes pour vérifier
display(merged_df.head())
# Out:
#    adult                     backdrop_path     tconst original_language  \
# 0  False  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg  tt0035423                en
# 1    NaN                               NaN  tt0096222               NaN
# 2  False  /6tRdTNdcmdBlTGyJ924ISyJDABA.jpg  tt0097106                fr
# 3  False  /uEPLeurEn2dp54f5owtMC3PeiPN.jpg  tt0097318                en
# 4  False  /inHgpiOAddL4Y53EvHf9B5lf2Sc.jpg  tt0097462                fr
#
#           original_title                                           overview  \
# 0         Kate & Leopold  When her scientist ex-boyfriend discovers a po...
# 1                    NaN                                                NaN
# 2     Conte de printemps  The story of an introverted young girl  just r...
# 3       Eye of the Widow  A new international terrorist group attack the...
# 4  Guerriers et Captives  Patagonia, Argentina, 1880s. During the Conque...
#
#    popularity                       poster_path production_countries  \
# 0      15.770  /mUvikzKJJSg9khrVdxK8kg3TMHA.jpg               ['US']
# 1         NaN                               NaN                  NaN
# 2       9.163  /bP2qpuzQPBBBJa4kOhvLvOOiASq.jpg               ['FR']
# 3       0.742  /1Ela9pkCRCPugwasp8hdR1BpfXb.jpg         ['ES', 'FR']
# 4       0.960  /ytYs98qqVmiY45cxkqNgJbj8uDL.jpg   ['AR', 'FR', 'CH']
#
#   release_date  ...     nconst category        types  startYear  \
# 0   2001-12-25  ...        NaN      NaN          NaN        NaN
# 1          NaT  ...  nm0510903    actor  imdbDisplay     1992.0
# 2   1990-04-04  ...        NaN      NaN          NaN        NaN
# 3   1991-10-17  ...        NaN      NaN          NaN        NaN
# 4   1990-09-05  ...        NaN      NaN          NaN        NaN
#
#   runtimeMinutes  primaryName  birthYear                             genres  \
# 0            NaN          NaN        NaN  ['Romance', 'Fantasy', 'Comedy'],
# 1           90.0    Jimmy Lin     1974.0              ,Comedy,Drama,Romance
# 2            NaN          NaN        NaN    ['Comedy', 'Drama', 'Romance'],
# 3            NaN          NaN        NaN  ['Crime', 'Action', 'Adventure'],
# 4            NaN          NaN        NaN            ['Drama', 'Adventure'],
#
#                       titles          languages_combined
# 0          Kate & Leopold -         ['en', 'fr', 'it'],
# 1        - To Miss with Love                        , en
# 2    A Tale of Springtime -                     ['fr'],
# 3        Eye of the Widow -   ['ar', 'en', 'fr', 'es'],
# 4  Warriors and Prisoners -               ['fr', 'es'],
#
# [5 rows x 29 columns]

# %%
# Trouver les NaN dans tout le DataFrame
nan_counts = merged_df.isna().sum()

# Afficher le nombre de NaN par colonne
print(nan_counts)
# Out:
# adult                        8299
# backdrop_path                9386
# tconst                          0
# overview                     8718
# popularity                   8299
# poster_path                  8449
# production_countries         8299
# status                       8299
# production_companies_name    8299
# averageRating                3462
# ordering                     3462
# category                     3462
# primaryName                  3462
# birthYear                    3462
# genres                          0
# titles                          0
# languages_combined              0
# votes                           0
# runtime                         0
# start_year                      0
# dtype: int64

# %%
# Combiner les colonnes 'vote_average' et 'numVotes' en une seule colonne
merged_df['votes'] = merged_df['vote_average'].fillna('').astype(str) + ' / ' + merged_df['numVotes'].fillna('').astype(str)

# Supprimer les colonnes 'vote_average' et 'numVotes'
merged_df = merged_df.drop(columns=['vote_average', 'numVotes'])

# Afficher les premières lignes pour vérifier
display(merged_df.head())
# Out:
#    adult                     backdrop_path     tconst original_language  \
# 0  False  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg  tt0035423                en
# 1    NaN                               NaN  tt0096222               NaN
# 2  False  /6tRdTNdcmdBlTGyJ924ISyJDABA.jpg  tt0097106                fr
# 3  False  /uEPLeurEn2dp54f5owtMC3PeiPN.jpg  tt0097318                en
# 4  False  /inHgpiOAddL4Y53EvHf9B5lf2Sc.jpg  tt0097462                fr
#
#           original_title                                           overview  \
# 0         Kate & Leopold  When her scientist ex-boyfriend discovers a po...
# 1                    NaN                                                NaN
# 2     Conte de printemps  The story of an introverted young girl  just r...
# 3       Eye of the Widow  A new international terrorist group attack the...
# 4  Guerriers et Captives  Patagonia, Argentina, 1880s. During the Conque...
#
#    popularity                       poster_path production_countries  \
# 0      15.770  /mUvikzKJJSg9khrVdxK8kg3TMHA.jpg               ['US']
# 1         NaN                               NaN                  NaN
# 2       9.163  /bP2qpuzQPBBBJa4kOhvLvOOiASq.jpg               ['FR']
# 3       0.742  /1Ela9pkCRCPugwasp8hdR1BpfXb.jpg         ['ES', 'FR']
# 4       0.960  /ytYs98qqVmiY45cxkqNgJbj8uDL.jpg   ['AR', 'FR', 'CH']
#
#   release_date  ...  category        types startYear runtimeMinutes  \
# 0   2001-12-25  ...       NaN          NaN       NaN            NaN
# 1          NaT  ...     actor  imdbDisplay    1992.0           90.0
# 2   1990-04-04  ...       NaN          NaN       NaN            NaN
# 3   1991-10-17  ...       NaN          NaN       NaN            NaN
# 4   1990-09-05  ...       NaN          NaN       NaN            NaN
#
#    primaryName  birthYear                             genres  \
# 0          NaN        NaN  ['Romance', 'Fantasy', 'Comedy'],
# 1    Jimmy Lin     1974.0              ,Comedy,Drama,Romance
# 2          NaN        NaN    ['Comedy', 'Drama', 'Romance'],
# 3          NaN        NaN  ['Crime', 'Action', 'Adventure'],
# 4          NaN        NaN            ['Drama', 'Adventure'],
#
#                       titles          languages_combined                 votes
# 0          Kate & Leopold -         ['en', 'fr', 'it'],               6.326 /
# 1        - To Miss with Love                        , en   / 54558.04810794954
# 2    A Tale of Springtime -                     ['fr'],                 6.9 /
# 3        Eye of the Widow -   ['ar', 'en', 'fr', 'es'],                 3.0 /
# 4  Warriors and Prisoners -               ['fr', 'es'],                 0.0 /
#
# [5 rows x 28 columns]

# %%
# Combiner les colonnes 'runtimeMinutes' et 'runtime' en une seule colonne
merged_df['runtime_combined'] = merged_df['runtimeMinutes'].fillna('').astype(str) + ' / ' + merged_df['runtime'].fillna('').astype(str)

# Supprimer les colonnes 'runtimeMinutes' et 'runtime'
merged_df = merged_df.drop(columns=['runtimeMinutes', 'runtime'])

# Afficher les premières lignes pour vérifier
display(merged_df.head())
# Out:
#    adult                     backdrop_path     tconst original_language  \
# 0  False  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg  tt0035423                en
# 1    NaN                               NaN  tt0096222               NaN
# 2  False  /6tRdTNdcmdBlTGyJ924ISyJDABA.jpg  tt0097106                fr
# 3  False  /uEPLeurEn2dp54f5owtMC3PeiPN.jpg  tt0097318                en
# 4  False  /inHgpiOAddL4Y53EvHf9B5lf2Sc.jpg  tt0097462                fr
#
#           original_title                                           overview  \
# 0         Kate & Leopold  When her scientist ex-boyfriend discovers a po...
# 1                    NaN                                                NaN
# 2     Conte de printemps  The story of an introverted young girl  just r...
# 3       Eye of the Widow  A new international terrorist group attack the...
# 4  Guerriers et Captives  Patagonia, Argentina, 1880s. During the Conque...
#
#    popularity                       poster_path production_countries  \
# 0      15.770  /mUvikzKJJSg9khrVdxK8kg3TMHA.jpg               ['US']
# 1         NaN                               NaN                  NaN
# 2       9.163  /bP2qpuzQPBBBJa4kOhvLvOOiASq.jpg               ['FR']
# 3       0.742  /1Ela9pkCRCPugwasp8hdR1BpfXb.jpg         ['ES', 'FR']
# 4       0.960  /ytYs98qqVmiY45cxkqNgJbj8uDL.jpg   ['AR', 'FR', 'CH']
#
#   release_date  ... category        types startYear  primaryName  birthYear  \
# 0   2001-12-25  ...      NaN          NaN       NaN          NaN        NaN
# 1          NaT  ...    actor  imdbDisplay    1992.0    Jimmy Lin     1974.0
# 2   1990-04-04  ...      NaN          NaN       NaN          NaN        NaN
# 3   1991-10-17  ...      NaN          NaN       NaN          NaN        NaN
# 4   1990-09-05  ...      NaN          NaN       NaN          NaN        NaN
#
#                               genres                     titles  \
# 0  ['Romance', 'Fantasy', 'Comedy'],          Kate & Leopold -
# 1              ,Comedy,Drama,Romance        - To Miss with Love
# 2    ['Comedy', 'Drama', 'Romance'],    A Tale of Springtime -
# 3  ['Crime', 'Action', 'Adventure'],        Eye of the Widow -
# 4            ['Drama', 'Adventure'],  Warriors and Prisoners -
#
#            languages_combined                 votes  runtime_combined
# 0        ['en', 'fr', 'it'],               6.326 /            / 118.0
# 1                        , en   / 54558.04810794954           90.0 /
# 2                    ['fr'],                 6.9 /            / 103.0
# 3  ['ar', 'en', 'fr', 'es'],                 3.0 /             / 95.0
# 4              ['fr', 'es'],                 0.0 /             / 99.0
#
# [5 rows x 27 columns]

# %%
# Renommer la colonne 'runtime_combined' en 'runtime'
merged_df = merged_df.rename(columns={'runtime_combined': 'runtime'})

# %%
# Combiner les colonnes 'release_year' et 'startYear' en une seule colonne
merged_df['start_year'] = merged_df['release_year'].fillna('').astype(str) + ' - ' + merged_df['startYear'].fillna('').astype(str)

# Supprimer les colonnes 'release_year' et 'startYear'
merged_df = merged_df.drop(columns=['release_year', 'startYear'])

# Afficher les premières lignes pour vérifier
display(merged_df.head(2))
# Out:
#    adult                     backdrop_path     tconst original_language  \
# 0  False  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg  tt0035423                en
# 1    NaN                               NaN  tt0096222               NaN
#
#    original_title                                           overview  \
# 0  Kate & Leopold  When her scientist ex-boyfriend discovers a po...
# 1             NaN                                                NaN
#
#    popularity                       poster_path production_countries  \
# 0       15.77  /mUvikzKJJSg9khrVdxK8kg3TMHA.jpg               ['US']
# 1         NaN                               NaN                  NaN
#
#   release_date  ... category        types primaryName  birthYear  \
# 0   2001-12-25  ...      NaN          NaN         NaN        NaN
# 1          NaT  ...    actor  imdbDisplay   Jimmy Lin     1974.0
#
#                               genres                titles  \
# 0  ['Romance', 'Fantasy', 'Comedy'],     Kate & Leopold -
# 1              ,Comedy,Drama,Romance   - To Miss with Love
#
#      languages_combined                 votes   runtime  start_year
# 0  ['en', 'fr', 'it'],               6.326 /    / 118.0   2001.0 -
# 1                  , en   / 54558.04810794954   90.0 /     - 1992.0
#
# [2 rows x 26 columns]

# %% [markdown]
# Supression des colonnes 'nconst', 'release_date'

# %%
merged_df = merged_df.drop(columns=['nconst', 'release_date'])

# %%
# Obtenir les valeurs uniques dans la colonne 'video'
video_unik = merged_df['video'].unique()
print(video_unik)
# Out:
# [False nan True]

# %%
#Supression de la colonnes 'video'
#merged_df = merged_df.drop(columns=['video'])

# %%
#Supression des colonnes spécifiées
#merged_df = merged_df.drop(columns=['original_language','original_title', 'types'])

# %%
# Renommer la colonne 'languages_combined' en 'spoken_languages'
merged_df = merged_df.rename(columns={'languages_combined': 'spoken_languages'})

# %%
# Trouver la médiane de la colonne 'averageRating'
median_value = merged_df['averageRating'].median()

# Remplacer les NaN par la médiane
merged_df['averageRating'] = merged_df['averageRating'].fillna(median_value)

# Vérifier que les NaN ont été remplacés
display(merged_df['averageRating'].head())
# Out:
# 0    6.400675
# 1    6.400675
# 2    6.400675
# 3    6.400675
# 4    6.400675
# Name: averageRating, dtype: float64

# %%
# Trouver la valeur la plus fréquente (mode) dans la colonne 'production_countries'
most_frequent_value = merged_df['production_countries'].mode()[0]

# Remplacer les NaN par la valeur la plus fréquente
merged_df['production_countries'] = merged_df['production_countries'].fillna(most_frequent_value)

# Vérifier que les NaN ont été remplacés
display(merged_df['production_countries'].head())
# Out:
# 0                ['US']
# 1                ['FR']
# 2                ['FR']
# 3          ['ES', 'FR']
# 4    ['AR', 'FR', 'CH']
# Name: production_countries, dtype: object

# %%
# Trouver la valeur la plus fréquente (mode) dans la colonne 'production_companies_name '
most_companies = merged_df['production_companies_name'].mode()[0]

# Remplacer les NaN par la valeur la plus fréquente
merged_df['production_companies_name'] = merged_df['production_companies_name'].fillna(most_companies)

# Vérifier que les NaN ont été remplacés
display(merged_df['production_companies_name'].head(2))
# Out:
# 0    ['Konrad Pictures', 'Miramax']
# 1                                []
# Name: production_companies_name, dtype: object

# %%
# Trouver la valeur la plus fréquente (mode) dans la colonne 'category'
most_frequent_category = merged_df['category'].mode()[0]

# Remplacer les NaN par la valeur la plus fréquente
merged_df['category'] = merged_df['category'].fillna(most_frequent_category)

# Vérifier le remplacement
display(merged_df[['category', 'primaryName']].head())
# Out:
#   category primaryName
# 0    actor         NaN
# 1    actor   Jimmy Lin
# 2    actor         NaN
# 3    actor         NaN
# 4    actor         NaN

# %%
# Remplacer les NaN dans 'primaryName' par 'Unknown'
merged_df['primaryName'] = merged_df['primaryName'].fillna('Unknown')

# Vérifier le remplacement
display(merged_df[['category', 'primaryName']].head())
# Out:
#   category primaryName
# 0    actor     Unknown
# 1    actor   Jimmy Lin
# 2    actor     Unknown
# 3    actor     Unknown
# 4    actor     Unknown

# %%
#Supression de la colonnes 'ordering'
merged_df = merged_df.drop(columns=['ordering'])

# %%
#Supression de la colonnes 'status'
merged_df = merged_df.drop(columns=['status'])

# %%
# Obtenir les valeurs uniques dans la colonne 'popularity'
popularity_unik = merged_df['popularity'].nunique()
print(popularity_unik)
# Out:
# 2674

# %%
#Supression de la colonnes 'popularity'
merged_df = merged_df.drop(columns=['popularity'])

# %%
# Calculer la médiane de la colonne 'birthYear'
median_birth_year = merged_df['birthYear'].median()

# Remplacer les NaN par la médiane
merged_df['birthYear'] = merged_df['birthYear'].fillna(median_birth_year)

# Vérifier le remplacement
display(merged_df['birthYear'].head())
# Out:
# 0    1981.0
# 1    1974.0
# 2    1981.0
# 3    1981.0
# 4    1981.0
# Name: birthYear, dtype: float64

# %%
# Définir une phrase fun et originale
replacement_phrase = "Découvrez cette incroyable aventure et laissez-vous surprendre par chaque tournant inattendu !"

# Remplacer les NaN dans la colonne 'overview'
merged_df['overview'] = merged_df['overview'].fillna(replacement_phrase)

# Vérifier le remplacement
display(merged_df['overview'].head())
# Out:
# 0    When her scientist ex-boyfriend discovers a po...
# 1    Découvrez cette incroyable aventure et laissez...
# 2    The story of an introverted young girl  just r...
# 3    A new international terrorist group attack the...
# 4    Patagonia, Argentina, 1880s. During the Conque...
# Name: overview, dtype: object

# %% [markdown]
# Pour remplacer les valeurs manquantes dans la colonne 'adult', qui est un booléen indiquant si le film est pour adultes ou non, il est courant de choisir une valeur par défaut. Voici quelques approches possibles :
#
# Remplacer par False (Non adulte) : C'est souvent une approche sûre car la majorité des films ne sont pas pour adultes.
# Remplacer par True (Adulte) : Si vous pensez que la majorité des valeurs manquantes sont des films pour adultes (moins courant).
# Analyser les données : Si possible, analyser les autres colonnes pour faire une supposition plus éclairée sur les valeurs manquantes.

# %%
# Remplacer les NaN dans la colonne 'adult' par False
merged_df['adult'] = merged_df['adult'].fillna(False)
# Out:
# C:\Users\Win10\AppData\Local\Temp\ipykernel_22604\2556394049.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_df['adult'] = merged_df['adult'].fillna(False)

# %%
# Trouver les NaN dans tout le DataFrame
nan_counts = merged_df.isna().sum()

# Afficher le nombre de NaN par colonne
print(nan_counts)
# Out:
# adult                           0
# backdrop_path                9386
# tconst                          0
# overview                        0
# poster_path                  8449
# production_countries            0
# production_companies_name       0
# averageRating                   0
# category                        0
# primaryName                     0
# birthYear                       0
# genres                          0
# titles                          0
# languages_combined              0
# votes                           0
# runtime                         0
# start_year                      0
# dtype: int64

# %%
# Supprimer les lignes avec des valeurs NaN dans la colonne 'backdrop_path'
df_clean = merged_df.dropna(subset=['poster_path'])

# %%
# Trouver les NaN dans tout le DataFrame
nan_counts = df_clean.isna().sum()

# Afficher le nombre de NaN par colonne
print(nan_counts)
# Out:
# adult                          0
# backdrop_path                945
# tconst                         0
# overview                       0
# poster_path                    0
# production_countries           0
# production_companies_name      0
# averageRating                  0
# category                       0
# primaryName                    0
# birthYear                      0
# genres                         0
# titles                         0
# languages_combined             0
# votes                          0
# runtime                        0
# start_year                     0
# dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3930 entries, 0 to 12377
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   adult                      3930 non-null   bool
#  1   backdrop_path              2985 non-null   object
#  2   tconst                     3930 non-null   object
#  3   overview                   3930 non-null   object
#  4   poster_path                3930 non-null   object
#  5   production_countries       3930 non-null   object
#  6   production_companies_name  3930 non-null   object
#  7   averageRating              3930 non-null   float64
#  8   category                   3930 non-null   object
#  9   primaryName                3930 non-null   object
#  10  birthYear                  3930 non-null   float64
#  11  genres                     3930 non-null   object
#  12  titles                     3930 non-null   object
#  13  languages_combined         3930 non-null   object
#  14  votes                      3930 non-null   object
#  15  runtime                    3930 non-null   object
#  16  start_year                 3930 non-null   object
# dtypes: bool(1), float64(2), object(14)
# memory usage: 525.8+ KB

# %%
# Supprimer la colonne 'backdrop_path'
final_df = df_clean.drop(columns=['backdrop_path'])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3930 entries, 0 to 12377
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   adult                      3930 non-null   bool
#  1   tconst                     3930 non-null   object
#  2   overview                   3930 non-null   object
#  3   poster_path                3930 non-null   object
#  4   production_countries       3930 non-null   object
#  5   production_companies_name  3930 non-null   object
#  6   averageRating              3930 non-null   float64
#  7   category                   3930 non-null   object
#  8   primaryName                3930 non-null   object
#  9   birthYear                  3930 non-null   float64
#  10  genres                     3930 non-null   object
#  11  titles                     3930 non-null   object
#  12  languages_combined         3930 non-null   object
#  13  votes                      3930 non-null   object
#  14  runtime                    3930 non-null   object
#  15  start_year                 3930 non-null   object
# dtypes: bool(1), float64(2), object(13)
# memory usage: 495.1+ KB

# %%
# Sauvegarder le DataFrame nettoyé 
final_df.to_csv('C:/Users/Win10/Desktop/projet 2 bdd/table_finale_final_df.csv', index=False)
