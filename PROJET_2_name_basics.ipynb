# %%
from datetime import datetime
from datetime import timedelta
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
url = "https://datasets.imdbws.com/name.basics.tsv.gz"
df1 = pd.read_csv(url, sep = '\t')

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13973374 entries, 0 to 13973373
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             object
#  1   primaryName        object
#  2   birthYear          object
#  3   deathYear          object
#  4   primaryProfession  object
#  5   knownForTitles     object
# dtypes: object(6)
# memory usage: 639.7+ MB
# None

# %% [markdown]
# on remarque que birthyear et deathyear sont objet
#
#
#  analyser les année de naissance acteur, peut etre enlevé les acteur

# %%
print(df1.shape)
# Out:
# (13973374, 6)

# %%
print(df1.head())
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                     primaryProfession                           knownForTitles
# 0        actor,miscellaneous,producer  tt0050419,tt0072308,tt0053137,tt0027125
# 1  actress,soundtrack,archive_footage  tt0037382,tt0075213,tt0117057,tt0038355
# 2   actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452
# 3       actor,writer,music_department  tt0072562,tt0077975,tt0080455,tt0078723
# 4               writer,director,actor  tt0050986,tt0069467,tt0050976,tt0083922

# %%
display(df1)
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 13973369  nm9993714   Romeo del Rosario        \N        \N
# 13973370  nm9993716       Essias Loberg        \N        \N
# 13973371  nm9993717  Harikrishnan Rajan        \N        \N
# 13973372  nm9993718         Aayush Nair        \N        \N
# 13973373  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0                actor,miscellaneous,producer
# 1          actress,soundtrack,archive_footage
# 2           actress,music_department,producer
# 3               actor,writer,music_department
# ...

# %%
print(df1.head().to_markdown())
# Out:
# |    | nconst    | primaryName     |   birthYear | deathYear   | primaryProfession                  | knownForTitles                          |
# |---:|:----------|:----------------|------------:|:------------|:-----------------------------------|:----------------------------------------|
# |  0 | nm0000001 | Fred Astaire    |        1899 | 1987        | actor,miscellaneous,producer       | tt0050419,tt0072308,tt0053137,tt0027125 |
# |  1 | nm0000002 | Lauren Bacall   |        1924 | 2014        | actress,soundtrack,archive_footage | tt0037382,tt0075213,tt0117057,tt0038355 |
# |  2 | nm0000003 | Brigitte Bardot |        1934 | \N          | actress,music_department,producer  | tt0057345,tt0049189,tt0056404,tt0054452 |
# |  3 | nm0000004 | John Belushi    |        1949 | 1982        | actor,writer,music_department      | tt0072562,tt0077975,tt0080455,tt0078723 |
# ...

# %%
#supprimer les films qui ont des '\N'
df1 = df1.replace('\\N',  np.nan)

# %%
# verinfier les NAN: on a 9 acteurs sans nom, donc à supprimer
print(df1.isna().sum())
# Out:
# nconst                      0
# primaryName                50
# birthYear            13341357
# deathYear            13736427
# primaryProfession     2710678
# knownForTitles        1578840
# dtype: int64

# %%
df1 = df1.dropna()

# %%
print(df1.isna().sum())
# Out:
# nconst               0
# primaryName          0
# birthYear            0
# deathYear            0
# primaryProfession    0
# knownForTitles       0
# dtype: int64

# %%
print(df1.head().to_markdown())
# Out:
# |    | nconst    | primaryName    |   birthYear |   deathYear | primaryProfession                  | knownForTitles                          |
# |---:|:----------|:---------------|------------:|------------:|:-----------------------------------|:----------------------------------------|
# |  0 | nm0000001 | Fred Astaire   |        1899 |        1987 | actor,miscellaneous,producer       | tt0050419,tt0072308,tt0053137,tt0027125 |
# |  1 | nm0000002 | Lauren Bacall  |        1924 |        2014 | actress,soundtrack,archive_footage | tt0037382,tt0075213,tt0117057,tt0038355 |
# |  3 | nm0000004 | John Belushi   |        1949 |        1982 | actor,writer,music_department      | tt0072562,tt0077975,tt0080455,tt0078723 |
# |  4 | nm0000005 | Ingmar Bergman |        1918 |        2007 | writer,director,actor              | tt0050986,tt0069467,tt0050976,tt0083922 |
# ...

# %%
# Supprimer les doublons
df1.drop_duplicates(inplace=True)

# %%
print(df1.shape)
# Out:
# (192473, 6)

# %%
year_now = datetime.now().year

# %%
df1['birthYear'] =df1['birthYear'].astype(int)

# %%
print(df1['birthYear'].dtype)
# Out:
# int64

# %%
print(df1['birthYear'].isna().sum())
# Out:
# 0

# %%
df1['deathYear'] =df1['deathYear'].astype(int)

# %%
print(df1['deathYear'].dtype)
# Out:
# int64

# %%
print(df1['deathYear'].isna().sum())
# Out:
# 0

# %%
# Utilisez la méthode describe() sur la colonne 'birthYear'
birthYear_describe = df1['birthYear'].describe(percentiles = np.arange(0.05,1,0.05))

print(birthYear_describe)
# Out:
# count    192473.000000
# mean       1920.826267
# std          35.804473
# min           4.000000
# 5%         1877.000000
# 10%        1888.000000
# 15%        1895.000000
# 20%        1901.000000
# 25%        1906.000000
# 30%        1910.000000
# 35%        1914.000000
# 40%        1918.000000
# 45%        1921.000000
# 50%        1924.000000
# 55%        1926.000000
# 60%        1929.000000
# 65%        1931.000000
# 70%        1934.000000
# 75%        1938.000000
# 80%        1942.000000
# 85%        1946.000000
# 90%        1952.000000
# 95%        1962.000000
# max        2022.000000
# Name: birthYear, dtype: float64

# %%
df1 = df1[df1['birthYear'] != 4]

# %%
# Convertir 'birthyear' et 'deathyear' en format date
#df_cleaned['birthYear']=pd.to_numeric(df_cleaned['birthYear'] , errors='coerce')
#df_cleaned['deathYear']= pd.to_numeric(df_cleaned['deathYear'], errors='coerce')

#describe sur les années
# Utilisez la méthode describe() sur la colonne 'birthYear'
birthYear_describe = df1['birthYear'].describe(percentiles = np.arange(0.05,1,0.05))
print(birthYear_describe)

#filtrer sur les dates

# Filtrer les lignes où 'birthYear' est supérieur à 1890
df1 = df1[df1['birthYear'] > 1890]

#stats sur death
stats = df1['deathYear'].describe()
print(stats)

df1 = df1[df1['deathYear'] > 1970]

#quelles sont les differentes profession
print(df1.primaryProfession.value_counts())

#role unique : (voir lc de rami avec split et explode)

# Divisez la colonne 'primaryProfession' en utilisant split et explode pour obtenir des valeurs uniques
test = df1['primaryProfession'].str.split(',')
df1_exploded = test.explode('primaryProfession')

# Trouvez les valeurs uniques dans la colonne 'primaryProfession'
unique_actor = df1_exploded.value_counts()

df1_names.to_csv("names_basics_clean.tsv.gz", index = False)

#stats sur les données numeriques
stats_deciles = df1.describe(percentiles = np.arange(0,1,0.01))
print(stats_deciles.to_markdown())
# Out:
# count     13981026
# unique         545
# top             \N
# freq      13348838
# Name: birthYear, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-54288342c5d6> in <cell line: 13>()
#      11
#      12 # Filtrer les lignes où 'birthYear' est supérieur à 1890
# ---> 13 df1 = df1[df1['birthYear'] > 1890]
#      14
#      15 #stats sur death
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
# ...
